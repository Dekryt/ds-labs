# %% [markdown]
# #Студенты группы ИНБс-5301
# ###  Симахин С.А., Игнатович В.О.
#
# #Лабораторная работа №1, файл №1
# #Вариант 26

# %% [markdown]
# #Определение функций:

# %%
def greet(name: str) -> str:
	return f"Привет, {name}!"
def compute_statistics(numbers):
	if not numbers:
		return None
	return {
		"count": len(numbers),
		"sum": sum(numbers),
		"min": min(numbers),
		"max": max(numbers),
		"avg": sum(numbers) / len(numbers),
	}

# %% [markdown]
# #Вызов функций:

# %%
# 1. Приветствие
print(greet("Студент"))
# 2. Работа со списком
sample = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3]
stats = compute_statistics(sample)
print(f"Список: {sample}")
for key, value in stats.items():
	print(f" {key:>5}: {value}")
# Out:
# Привет, Студент!
# Список: [3, 1, 4, 1, 5, 9, 2, 6, 5, 3]
#  count: 10
#    sum: 39
#    min: 1
#    max: 9
#    avg: 3.9

# %% [markdown]
# #Добавление рекурсивной функции:

# %%
"""Рекурсивный факториал. n >= 0."""
def factorial(n: int) -> int:
	if n < 0:
		raise ValueError("factorial не определён для отрицательных чисел")
	return 1 if n <= 1 else n * factorial(n - 1)

# %% [markdown]
# #Вызов рекурсивной функции:

# %%
print(f"5! = {factorial(5)}")
print(f"10! = {factorial(10)}")
# Out:
# 5! = 120
# 10! = 3628800
